# %%
cd
# Out:
# /home/stasya

# %%
cd SIT_FUSE/src/sit_fuse/preprocessing
# Out:
# /home/stasya/SIT_FUSE/src/sit_fuse/preprocessing

# %%
! python3 colocate_and_resample.py -y ../config/preprocess/colocate_and_resample/fuse_gk2a_stasya.yaml
# Out:
# 33 33
# (2600, 3000) (2600, 3000)
# (2600, 3000) (2600, 3000)
# (2600, 3000) (2600, 3000)
# (2600, 3000) (2600, 3000)
# (2600, 3000) (2600, 3000)
# (2600, 3000) (2600, 3000)
# (2600, 3000) (2600, 3000)
# (2600, 3000) (2600, 3000)
# (2600, 3000) (2600, 3000)
# (5200, 6000) (2600, 3000)
# (5200, 6000) (2600, 3000)
# (10400, 12000) (2600, 3000)
# (5200, 6000) (2600, 3000)
# (2600, 3000) (2600, 3000)
# (2600, 3000) (2600, 3000)
# (2600, 3000) (2600, 3000)
# (16, 2600, 3000)
# (16, 2600, 3000)
# (2, 2600, 3000) /data/nlahaye/remoteSensing/GK2A/GK2A/gk2a_ami_ea020lc_latlon.nc
# (16, 2600, 3000) (2, 2600, 3000)
# (2600, 3000, 16) (2600, 3000, 2)
# 0.0 16342.0 1e-07 100000000
# (2600, 3000, 1)
# (76.81183, 11.30853, 175.18817, 61.93105) 0.0 16342.0
# S. Korea {'proj': 'longlat', 'datum': 'WGS84'} (76.81183, 11.30853, 175.18817, 61.93105) 0.018 degrees
# WARNING:root:shape found from radius and resolution does not contain only integers: (2812.362194061173, 5465.352376301877)
# ...
